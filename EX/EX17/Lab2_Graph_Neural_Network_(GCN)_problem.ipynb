# %% [markdown]
# # Introduction

# %% [markdown]
# Welcome to this lab!
# At this lab, we will learn how to implement Graph Convolutional Networks (GCN) based on the paper [GCN](https://arxiv.org/pdf/1609.02907.pdf).

# %% [markdown]
# # Exercise

# %% [markdown]
# ## Download data and install packages

# %%
# !gdown --id "1Z748ksOFWZ8WLsy0P8T7eYA6XLVLieX3&export=download"
# !unrar x -Y "/content/lab2.rar" -d "/content/"
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1Z748ksOFWZ8WLsy0P8T7eYA6XLVLieX3&export=download
# To: /content/lab2.rar
# 100% 599/599 [00:00<00:00, 2.60MB/s]
#
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from /content/lab2.rar
#
#   OK
#   OK
# All OK

# %% [markdown]
# ## Packages: Import neccesary packages

# %%
import torch
import torch.nn as nn
import numpy as np
import networkx as nx
import torch.optim as optim
import torch.nn.functional as F
import pandas as pd

# %% [markdown]
# ## Utils: Processing data

# %%
def create_graphs_with_attributes(edgelist_filepath,attributes_filepath):
    graph=nx.read_edgelist(edgelist_filepath,nodetype=int)
    attributes=pd.read_csv(attributes_filepath,index_col=['node'])
    att_values = {a:{'role':b[0],'community':b[1]} for a,b in enumerate(attributes.values)}
    nx.set_node_attributes(graph,att_values)
    return graph


def create_train_test(graph):
    X_train,Y_train,X_test,Y_test=[],[],[],[]
    for node, data in graph.nodes(data=True):
        if data['role'] in ['Administrator','Instructor']:
            X_train.append(node)
            Y_train.append(data['role']=='Administrator')
        elif data['role'] =='Member':
            X_test.append(node)
            Y_test.append(data['community']=='Administrator')
    return np.asarray(X_train),np.asarray(Y_train),np.asarray(X_test),np.asarray(Y_test)



def create_features(graph): # create input features, concatenation of identity matrix and shortest paths to targets
    A = nx.to_numpy_array(graph)
    X_1 = torch.eye(A.shape[0]) # identity matrix
    X_2 = torch.zeros((A.shape[0], 2)) # shortest path to the targets as 2nd input feature
    node_distance_instructor = nx.shortest_path_length(graph, target=33)
    node_distance_administrator = nx.shortest_path_length(graph, target=0)

    for node in graph.nodes():
        X_2[node][0] = node_distance_administrator[node]
        X_2[node][1] = node_distance_instructor[node]

    return torch.cat((X_1,X_2),dim=1)

# %% [markdown]
# ## TO DO: Implement Graph Convolutional Networks (GCN)

# %% [markdown]
# ![GCN.PNG](data:image/png;base64,...)

# %%
from torch.nn.parameter import Parameter

class GCN_layer(nn.Module):
    """
      Define filter layer 1/2 like in the above image
      Calculate A_hat first then,
      Input: adj_matrix with input features X
    """

    def __init__(self, inputs_shape, outputs_shape):
        super(GCN_layer, self).__init__()

        self.W=Parameter(torch.rand(inputs_shape,outputs_shape),requires_grad=True)
        self.bias = Parameter(torch.rand(outputs_shape),requires_grad=True)


    def forward(self, adj_matrix, input_features):
        # TO DO: Calculate A_hat
        A = torch.from_numpy(adj_matrix).type(torch.LongTensor)
        I = torch.eye(A.shape[0])
        A_hat = A + I
        D = torch.diag(torch.sum(A_hat, dim = 1))
        D = torch.sqrt(D)
        D = torch.linalg.inv(D)
        A_hat = torch.mm(torch.mm(D, A_hat), D)
        aggregate=torch.mm(A_hat,input_features)
        propagate=torch.mm(aggregate,self.W)+self.bias
        return propagate

# %%
class GCN(nn.Module):


    def __init__(self,inputs_shape,outputs_shape,n_classes,activation='Relu'):
        super(GCN, self).__init__()

        self.layer1=GCN_layer(inputs_shape,outputs_shape)
        self.layer2=GCN_layer(outputs_shape,n_classes)


        if activation =='Tanh':
            self.activation = nn.Tanh()
        elif activation=='Sigmoid':
            self.activation = nn.Sigmoid()
        elif activation=='Softmax':
            self.activation=nn.Softmax()
        elif activation=='Relu':
            self.activation=nn.ReLU()

        self.softmax=nn.Softmax()


    def forward(self,adj_matrix,input_features):
        # TO DO: Define output for each layer. Please look at the method in the picture above
        x = self.layer1(adj_matrix, input_features)
        x = self.activation(x)
        x = self.layer2(adj_matrix, x)
        x = self.softmax(x)
        return x

# %%
import torch
from sklearn.metrics import classification_report
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import networkx as nx


graph=create_graphs_with_attributes('lab2_edgelist.txt','lab2_attributes.csv')
A = nx.to_numpy_array(graph) # adjadjency matrix

class Trainer():
    def __init__(self,model,optimizer,loss_function,epochs):

        self.model=model
        self.optimizer=optimizer
        self.loss_function=loss_function
        self.epochs=epochs

    def train(self,X_train,Y_train):

        y_train=torch.from_numpy(Y_train.astype(int)).type(torch.LongTensor)
        tot_loss=0.0
        all_preds=[]

        for t in range(self.epochs):
            epoch_loss = 0.0

            #model.train()
            y_pred=self.model(A, create_features(graph))
            all_preds.append(y_pred)
            loss = self.loss_function(y_pred[X_train], y_train)
            self.optimizer.zero_grad()
            epoch_loss+=loss
            tot_loss+=loss
            loss.backward()
            self.optimizer.step()

            print(str(t),'epoch_loss:'+str(epoch_loss),'total loss:'+str(tot_loss))

        self.all_preds=all_preds

    def test(self,X_test,Y_test):

        self.model.eval()
        y_test=torch.from_numpy(Y_test.astype(int)).type(torch.LongTensor)
        y_pred=self.all_preds[-1]  # preds of last epoch
        loss_test = self.loss_function(y_pred[X_test],y_test)
        print('validation loss is equal to: '+str(loss_test))

    def visualize_classification(self,graph,Y_test,classification):
        last_epoch = self.all_preds[self.epochs-1].detach().numpy() # get outputs of last epoch
        predicted_class = np.argmax(last_epoch, axis=-1) # take the unit with the higher probability
        color = np.where(predicted_class==0, 'c', 'r')
        pos = nx.kamada_kawai_layout(graph)
        nx.draw_networkx(graph, pos, node_color=color, with_labels=True, node_size=300)
        if classification==True:
            print(classification_report(predicted_class[1:-1],Y_test))

# %% [markdown]
# ## Run GCN

# %%
graph=create_graphs_with_attributes('lab2_edgelist.txt','lab2_attributes.csv')
A = nx.to_numpy_array(graph) # adjadjency matrix
X_train,Y_train,X_test,Y_test= create_train_test(graph)

model=GCN(inputs_shape=create_features(graph).shape[1],outputs_shape=4,n_classes=2,activation='Relu')
trainer = Trainer(
    model,
    optimizer = optim.Adam(model.parameters(), lr=0.01),
    loss_function=F.cross_entropy,
    epochs=250
)

trainer.train(X_train,Y_train)
trainer.test(X_test,Y_test)
trainer.visualize_classification(graph,Y_test,classification=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1773: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# 0 epoch_loss:tensor(0.6451, grad_fn=<AddBackward0>) total loss:tensor(0.6451, grad_fn=<AddBackward0>)
# 1 epoch_loss:tensor(0.6243, grad_fn=<AddBackward0>) total loss:tensor(1.2694, grad_fn=<AddBackward0>)
# 2 epoch_loss:tensor(0.6077, grad_fn=<AddBackward0>) total loss:tensor(1.8771, grad_fn=<AddBackward0>)
# 3 epoch_loss:tensor(0.5973, grad_fn=<AddBackward0>) total loss:tensor(2.4744, grad_fn=<AddBackward0>)
# 4 epoch_loss:tensor(0.5923, grad_fn=<AddBackward0>) total loss:tensor(3.0667, grad_fn=<AddBackward0>)
# 5 epoch_loss:tensor(0.5889, grad_fn=<AddBackward0>) total loss:tensor(3.6556, grad_fn=<AddBackward0>)
# 6 epoch_loss:tensor(0.5833, grad_fn=<AddBackward0>) total loss:tensor(4.2389, grad_fn=<AddBackward0>)
# 7 epoch_loss:tensor(0.5750, grad_fn=<AddBackward0>) total loss:tensor(4.8139, grad_fn=<AddBackward0>)
# 8 epoch_loss:tensor(0.5653, grad_fn=<AddBackward0>) total loss:tensor(5.3792, grad_fn=<AddBackward0>)
# 9 epoch_loss:tensor(0.5556, grad_fn=<AddBackward0>) total loss:tensor(5.9348, grad_fn=<AddBackward0>)
# 10 epoch_loss:tensor(0.5469, grad_fn=<AddBackward0>) total loss:tensor(6.4817, grad_fn=<AddBackward0>)
# 11 epoch_loss:tensor(0.5393, grad_fn=<AddBackward0>) total loss:tensor(7.0210, grad_fn=<AddBackward0>)
# 12 epoch_loss:tensor(0.5323, grad_fn=<AddBackward0>) total loss:tensor(7.5533, grad_fn=<AddBackward0>)
# 13 epoch_loss:tensor(0.5254, grad_fn=<AddBackward0>) total loss:tensor(8.0787, grad_fn=<AddBackward0>)
# 14 epoch_loss:tensor(0.5183, grad_fn=<AddBackward0>) total loss:tensor(8.5970, grad_fn=<AddBackward0>)
# 15 epoch_loss:tensor(0.5107, grad_fn=<AddBackward0>) total loss:tensor(9.1077, grad_fn=<AddBackward0>)
# 16 epoch_loss:tensor(0.5027, grad_fn=<AddBackward0>) total loss:tensor(9.6104, grad_fn=<AddBackward0>)
# 17 epoch_loss:tensor(0.4945, grad_fn=<AddBackward0>) total loss:tensor(10.1049, grad_fn=<AddBackward0>)
# 18 epoch_loss:tensor(0.4864, grad_fn=<AddBackward0>) total loss:tensor(10.5914, grad_fn=<AddBackward0>)
# 19 epoch_loss:tensor(0.4786, grad_fn=<AddBackward0>) total loss:tensor(11.0700, grad_fn=<AddBackward0>)
# 20 epoch_loss:tensor(0.4712, grad_fn=<AddBackward0>) total loss:tensor(11.5413, grad_fn=<AddBackward0>)
# 21 epoch_loss:tensor(0.4642, grad_fn=<AddBackward0>) total loss:tensor(12.0054, grad_fn=<AddBackward0>)
# 22 epoch_loss:tensor(0.4573, grad_fn=<AddBackward0>) total loss:tensor(12.4628, grad_fn=<AddBackward0>)
# 23 epoch_loss:tensor(0.4506, grad_fn=<AddBackward0>) total loss:tensor(12.9133, grad_fn=<AddBackward0>)
# 24 epoch_loss:tensor(0.4438, grad_fn=<AddBackward0>) total loss:tensor(13.3571, grad_fn=<AddBackward0>)
# 25 epoch_loss:tensor(0.4370, grad_fn=<AddBackward0>) total loss:tensor(13.7941, grad_fn=<AddBackward0>)
# 26 epoch_loss:tensor(0.4303, grad_fn=<AddBackward0>) total loss:tensor(14.2243, grad_fn=<AddBackward0>)
# 27 epoch_loss:tensor(0.4237, grad_fn=<AddBackward0>) total loss:tensor(14.6481, grad_fn=<AddBackward0>)
# 28 epoch_loss:tensor(0.4175, grad_fn=<AddBackward0>) total loss:tensor(15.0655, grad_fn=<AddBackward0>)
# 29 epoch_loss:tensor(0.4115, grad_fn=<AddBackward0>) total loss:tensor(15.4770, grad_fn=<AddBackward0>)
# 30 epoch_loss:tensor(0.4058, grad_fn=<AddBackward0>) total loss:tensor(15.8828, grad_fn=<AddBackward0>)
# 31 epoch_loss:tensor(0.4004, grad_fn=<AddBackward0>) total loss:tensor(16.2832, grad_fn=<AddBackward0>)
# 32 epoch_loss:tensor(0.3953, grad_fn=<AddBackward0>) total loss:tensor(16.6785, grad_fn=<AddBackward0>)
# 33 epoch_loss:tensor(0.3904, grad_fn=<AddBackward0>) total loss:tensor(17.0689, grad_fn=<AddBackward0>)
# 34 epoch_loss:tensor(0.3857, grad_fn=<AddBackward0>) total loss:tensor(17.4546, grad_fn=<AddBackward0>)
# 35 epoch_loss:tensor(0.3812, grad_fn=<AddBackward0>) total loss:tensor(17.8358, grad_fn=<AddBackward0>)
# 36 epoch_loss:tensor(0.3770, grad_fn=<AddBackward0>) total loss:tensor(18.2128, grad_fn=<AddBackward0>)
# 37 epoch_loss:tensor(0.3730, grad_fn=<AddBackward0>) total loss:tensor(18.5858, grad_fn=<AddBackward0>)
# 38 epoch_loss:tensor(0.3692, grad_fn=<AddBackward0>) total loss:tensor(18.9550, grad_fn=<AddBackward0>)
# 39 epoch_loss:tensor(0.3657, grad_fn=<AddBackward0>) total loss:tensor(19.3207, grad_fn=<AddBackward0>)
# 40 epoch_loss:tensor(0.3624, grad_fn=<AddBackward0>) total loss:tensor(19.6831, grad_fn=<AddBackward0>)
# 41 epoch_loss:tensor(0.3594, grad_fn=<AddBackward0>) total loss:tensor(20.0425, grad_fn=<AddBackward0>)
# 42 epoch_loss:tensor(0.3565, grad_fn=<AddBackward0>) total loss:tensor(20.3990, grad_fn=<AddBackward0>)
# 43 epoch_loss:tensor(0.3539, grad_fn=<AddBackward0>) total loss:tensor(20.7528, grad_fn=<AddBackward0>)
# 44 epoch_loss:tensor(0.3514, grad_fn=<AddBackward0>) total loss:tensor(21.1042, grad_fn=<AddBackward0>)
# 45 epoch_loss:tensor(0.3491, grad_fn=<AddBackward0>) total loss:tensor(21.4533, grad_fn=<AddBackward0>)
# 46 epoch_loss:tensor(0.3469, grad_fn=<AddBackward0>) total loss:tensor(21.8002, grad_fn=<AddBackward0>)
# 47 epoch_loss:tensor(0.3449, grad_fn=<AddBackward0>) total loss:tensor(22.1451, grad_fn=<AddBackward0>)
# 48 epoch_loss:tensor(0.3430, grad_fn=<AddBackward0>) total loss:tensor(22.4881, grad_fn=<AddBackward0>)
# 49 epoch_loss:tensor(0.3413, grad_fn=<AddBackward0>) total loss:tensor(22.8294, grad_fn=<AddBackward0>)
# 50 epoch_loss:tensor(0.3397, grad_fn=<AddBackward0>) total loss:tensor(23.1691, grad_fn=<AddBackward0>)
# 51 epoch_loss:tensor(0.3382, grad_fn=<AddBackward0>) total loss:tensor(23.5072, grad_fn=<AddBackward0>)
# 52 epoch_loss:tensor(0.3368, grad_fn=<AddBackward0>) total loss:tensor(23.8440, grad_fn=<AddBackward0>)
# 53 epoch_loss:tensor(0.3355, grad_fn=<AddBackward0>) total loss:tensor(24.1795, grad_fn=<AddBackward0>)
# 54 epoch_loss:tensor(0.3343, grad_fn=<AddBackward0>) total loss:tensor(24.5138, grad_fn=<AddBackward0>)
# 55 epoch_loss:tensor(0.3332, grad_fn=<AddBackward0>) total loss:tensor(24.8470, grad_fn=<AddBackward0>)
# 56 epoch_loss:tensor(0.3322, grad_fn=<AddBackward0>) total loss:tensor(25.1792, grad_fn=<AddBackward0>)
# 57 epoch_loss:tensor(0.3312, grad_fn=<AddBackward0>) total loss:tensor(25.5104, grad_fn=<AddBackward0>)
# 58 epoch_loss:tensor(0.3303, grad_fn=<AddBackward0>) total loss:tensor(25.8407, grad_fn=<AddBackward0>)
# 59 epoch_loss:tensor(0.3295, grad_fn=<AddBackward0>) total loss:tensor(26.1702, grad_fn=<AddBackward0>)
# 60 epoch_loss:tensor(0.3287, grad_fn=<AddBackward0>) total loss:tensor(26.4989, grad_fn=<AddBackward0>)
# 61 epoch_loss:tensor(0.3281, grad_fn=<AddBackward0>) total loss:tensor(26.8270, grad_fn=<AddBackward0>)
# 62 epoch_loss:tensor(0.3274, grad_fn=<AddBackward0>) total loss:tensor(27.1544, grad_fn=<AddBackward0>)
# 63 epoch_loss:tensor(0.3268, grad_fn=<AddBackward0>) total loss:tensor(27.4812, grad_fn=<AddBackward0>)
# 64 epoch_loss:tensor(0.3262, grad_fn=<AddBackward0>) total loss:tensor(27.8074, grad_fn=<AddBackward0>)
# 65 epoch_loss:tensor(0.3257, grad_fn=<AddBackward0>) total loss:tensor(28.1331, grad_fn=<AddBackward0>)
# 66 epoch_loss:tensor(0.3252, grad_fn=<AddBackward0>) total loss:tensor(28.4583, grad_fn=<AddBackward0>)
# 67 epoch_loss:tensor(0.3248, grad_fn=<AddBackward0>) total loss:tensor(28.7831, grad_fn=<AddBackward0>)
# 68 epoch_loss:tensor(0.3243, grad_fn=<AddBackward0>) total loss:tensor(29.1074, grad_fn=<AddBackward0>)
# 69 epoch_loss:tensor(0.3239, grad_fn=<AddBackward0>) total loss:tensor(29.4313, grad_fn=<AddBackward0>)
# 70 epoch_loss:tensor(0.3235, grad_fn=<AddBackward0>) total loss:tensor(29.7548, grad_fn=<AddBackward0>)
# 71 epoch_loss:tensor(0.3232, grad_fn=<AddBackward0>) total loss:tensor(30.0780, grad_fn=<AddBackward0>)
# 72 epoch_loss:tensor(0.3228, grad_fn=<AddBackward0>) total loss:tensor(30.4008, grad_fn=<AddBackward0>)
# 73 epoch_loss:tensor(0.3225, grad_fn=<AddBackward0>) total loss:tensor(30.7233, grad_fn=<AddBackward0>)
# 74 epoch_loss:tensor(0.3222, grad_fn=<AddBackward0>) total loss:tensor(31.0455, grad_fn=<AddBackward0>)
# 75 epoch_loss:tensor(0.3219, grad_fn=<AddBackward0>) total loss:tensor(31.3674, grad_fn=<AddBackward0>)
# 76 epoch_loss:tensor(0.3216, grad_fn=<AddBackward0>) total loss:tensor(31.6891, grad_fn=<AddBackward0>)
# 77 epoch_loss:tensor(0.3214, grad_fn=<AddBackward0>) total loss:tensor(32.0105, grad_fn=<AddBackward0>)
# 78 epoch_loss:tensor(0.3211, grad_fn=<AddBackward0>) total loss:tensor(32.3316, grad_fn=<AddBackward0>)
# 79 epoch_loss:tensor(0.3209, grad_fn=<AddBackward0>) total loss:tensor(32.6525, grad_fn=<AddBackward0>)
# 80 epoch_loss:tensor(0.3207, grad_fn=<AddBackward0>) total loss:tensor(32.9732, grad_fn=<AddBackward0>)
# 81 epoch_loss:tensor(0.3205, grad_fn=<AddBackward0>) total loss:tensor(33.2937, grad_fn=<AddBackward0>)
# 82 epoch_loss:tensor(0.3203, grad_fn=<AddBackward0>) total loss:tensor(33.6139, grad_fn=<AddBackward0>)
# 83 epoch_loss:tensor(0.3201, grad_fn=<AddBackward0>) total loss:tensor(33.9340, grad_fn=<AddBackward0>)
# 84 epoch_loss:tensor(0.3199, grad_fn=<AddBackward0>) total loss:tensor(34.2539, grad_fn=<AddBackward0>)
# 85 epoch_loss:tensor(0.3197, grad_fn=<AddBackward0>) total loss:tensor(34.5736, grad_fn=<AddBackward0>)
# 86 epoch_loss:tensor(0.3196, grad_fn=<AddBackward0>) total loss:tensor(34.8932, grad_fn=<AddBackward0>)
# 87 epoch_loss:tensor(0.3194, grad_fn=<AddBackward0>) total loss:tensor(35.2126, grad_fn=<AddBackward0>)
# 88 epoch_loss:tensor(0.3193, grad_fn=<AddBackward0>) total loss:tensor(35.5319, grad_fn=<AddBackward0>)
# 89 epoch_loss:tensor(0.3191, grad_fn=<AddBackward0>) total loss:tensor(35.8510, grad_fn=<AddBackward0>)
# 90 epoch_loss:tensor(0.3190, grad_fn=<AddBackward0>) total loss:tensor(36.1699, grad_fn=<AddBackward0>)
# 91 epoch_loss:tensor(0.3188, grad_fn=<AddBackward0>) total loss:tensor(36.4888, grad_fn=<AddBackward0>)
# 92 epoch_loss:tensor(0.3187, grad_fn=<AddBackward0>) total loss:tensor(36.8075, grad_fn=<AddBackward0>)
# 93 epoch_loss:tensor(0.3186, grad_fn=<AddBackward0>) total loss:tensor(37.1261, grad_fn=<AddBackward0>)
# 94 epoch_loss:tensor(0.3185, grad_fn=<AddBackward0>) total loss:tensor(37.4446, grad_fn=<AddBackward0>)
# 95 epoch_loss:tensor(0.3184, grad_fn=<AddBackward0>) total loss:tensor(37.7629, grad_fn=<AddBackward0>)
# 96 epoch_loss:tensor(0.3182, grad_fn=<AddBackward0>) total loss:tensor(38.0812, grad_fn=<AddBackward0>)
# 97 epoch_loss:tensor(0.3181, grad_fn=<AddBackward0>) total loss:tensor(38.3993, grad_fn=<AddBackward0>)
# 98 epoch_loss:tensor(0.3180, grad_fn=<AddBackward0>) total loss:tensor(38.7173, grad_fn=<AddBackward0>)
# 99 epoch_loss:tensor(0.3179, grad_fn=<AddBackward0>) total loss:tensor(39.0353, grad_fn=<AddBackward0>)
# 100 epoch_loss:tensor(0.3178, grad_fn=<AddBackward0>) total loss:tensor(39.3531, grad_fn=<AddBackward0>)
# 101 epoch_loss:tensor(0.3178, grad_fn=<AddBackward0>) total loss:tensor(39.6709, grad_fn=<AddBackward0>)
# 102 epoch_loss:tensor(0.3177, grad_fn=<AddBackward0>) total loss:tensor(39.9886, grad_fn=<AddBackward0>)
# 103 epoch_loss:tensor(0.3176, grad_fn=<AddBackward0>) total loss:tensor(40.3061, grad_fn=<AddBackward0>)
# 104 epoch_loss:tensor(0.3175, grad_fn=<AddBackward0>) total loss:tensor(40.6236, grad_fn=<AddBackward0>)
# 105 epoch_loss:tensor(0.3174, grad_fn=<AddBackward0>) total loss:tensor(40.9411, grad_fn=<AddBackward0>)
# 106 epoch_loss:tensor(0.3173, grad_fn=<AddBackward0>) total loss:tensor(41.2584, grad_fn=<AddBackward0>)
# 107 epoch_loss:tensor(0.3173, grad_fn=<AddBackward0>) total loss:tensor(41.5757, grad_fn=<AddBackward0>)
# 108 epoch_loss:tensor(0.3172, grad_fn=<AddBackward0>) total loss:tensor(41.8929, grad_fn=<AddBackward0>)
# 109 epoch_loss:tensor(0.3171, grad_fn=<AddBackward0>) total loss:tensor(42.2100, grad_fn=<AddBackward0>)
# 110 epoch_loss:tensor(0.3171, grad_fn=<AddBackward0>) total loss:tensor(42.5271, grad_fn=<AddBackward0>)
# 111 epoch_loss:tensor(0.3170, grad_fn=<AddBackward0>) total loss:tensor(42.8440, grad_fn=<AddBackward0>)
# 112 epoch_loss:tensor(0.3169, grad_fn=<AddBackward0>) total loss:tensor(43.1610, grad_fn=<AddBackward0>)
# 113 epoch_loss:tensor(0.3169, grad_fn=<AddBackward0>) total loss:tensor(43.4778, grad_fn=<AddBackward0>)
# 114 epoch_loss:tensor(0.3168, grad_fn=<AddBackward0>) total loss:tensor(43.7946, grad_fn=<AddBackward0>)
# 115 epoch_loss:tensor(0.3167, grad_fn=<AddBackward0>) total loss:tensor(44.1114, grad_fn=<AddBackward0>)
# 116 epoch_loss:tensor(0.3167, grad_fn=<AddBackward0>) total loss:tensor(44.4281, grad_fn=<AddBackward0>)
# 117 epoch_loss:tensor(0.3166, grad_fn=<AddBackward0>) total loss:tensor(44.7447, grad_fn=<AddBackward0>)
# 118 epoch_loss:tensor(0.3166, grad_fn=<AddBackward0>) total loss:tensor(45.0613, grad_fn=<AddBackward0>)
# 119 epoch_loss:tensor(0.3165, grad_fn=<AddBackward0>) total loss:tensor(45.3778, grad_fn=<AddBackward0>)
# 120 epoch_loss:tensor(0.3165, grad_fn=<AddBackward0>) total loss:tensor(45.6943, grad_fn=<AddBackward0>)
# 121 epoch_loss:tensor(0.3164, grad_fn=<AddBackward0>) total loss:tensor(46.0107, grad_fn=<AddBackward0>)
# 122 epoch_loss:tensor(0.3164, grad_fn=<AddBackward0>) total loss:tensor(46.3270, grad_fn=<AddBackward0>)
# 123 epoch_loss:tensor(0.3163, grad_fn=<AddBackward0>) total loss:tensor(46.6434, grad_fn=<AddBackward0>)
# 124 epoch_loss:tensor(0.3163, grad_fn=<AddBackward0>) total loss:tensor(46.9596, grad_fn=<AddBackward0>)
# 125 epoch_loss:tensor(0.3162, grad_fn=<AddBackward0>) total loss:tensor(47.2759, grad_fn=<AddBackward0>)
# 126 epoch_loss:tensor(0.3162, grad_fn=<AddBackward0>) total loss:tensor(47.5921, grad_fn=<AddBackward0>)
# 127 epoch_loss:tensor(0.3161, grad_fn=<AddBackward0>) total loss:tensor(47.9082, grad_fn=<AddBackward0>)
# 128 epoch_loss:tensor(0.3161, grad_fn=<AddBackward0>) total loss:tensor(48.2243, grad_fn=<AddBackward0>)
# 129 epoch_loss:tensor(0.3161, grad_fn=<AddBackward0>) total loss:tensor(48.5404, grad_fn=<AddBackward0>)
# 130 epoch_loss:tensor(0.3160, grad_fn=<AddBackward0>) total loss:tensor(48.8564, grad_fn=<AddBackward0>)
# 131 epoch_loss:tensor(0.3160, grad_fn=<AddBackward0>) total loss:tensor(49.1724, grad_fn=<AddBackward0>)
# 132 epoch_loss:tensor(0.3159, grad_fn=<AddBackward0>) total loss:tensor(49.4883, grad_fn=<AddBackward0>)
# 133 epoch_loss:tensor(0.3159, grad_fn=<AddBackward0>) total loss:tensor(49.8042, grad_fn=<AddBackward0>)
# 134 epoch_loss:tensor(0.3159, grad_fn=<AddBackward0>) total loss:tensor(50.1201, grad_fn=<AddBackward0>)
# 135 epoch_loss:tensor(0.3158, grad_fn=<AddBackward0>) total loss:tensor(50.4359, grad_fn=<AddBackward0>)
# 136 epoch_loss:tensor(0.3158, grad_fn=<AddBackward0>) total loss:tensor(50.7517, grad_fn=<AddBackward0>)
# 137 epoch_loss:tensor(0.3158, grad_fn=<AddBackward0>) total loss:tensor(51.0675, grad_fn=<AddBackward0>)
# 138 epoch_loss:tensor(0.3157, grad_fn=<AddBackward0>) total loss:tensor(51.3832, grad_fn=<AddBackward0>)
# 139 epoch_loss:tensor(0.3157, grad_fn=<AddBackward0>) total loss:tensor(51.6989, grad_fn=<AddBackward0>)
# 140 epoch_loss:tensor(0.3157, grad_fn=<AddBackward0>) total loss:tensor(52.0145, grad_fn=<AddBackward0>)
# 141 epoch_loss:tensor(0.3156, grad_fn=<AddBackward0>) total loss:tensor(52.3302, grad_fn=<AddBackward0>)
# 142 epoch_loss:tensor(0.3156, grad_fn=<AddBackward0>) total loss:tensor(52.6458, grad_fn=<AddBackward0>)
# 143 epoch_loss:tensor(0.3156, grad_fn=<AddBackward0>) total loss:tensor(52.9614, grad_fn=<AddBackward0>)
# 144 epoch_loss:tensor(0.3155, grad_fn=<AddBackward0>) total loss:tensor(53.2769, grad_fn=<AddBackward0>)
# 145 epoch_loss:tensor(0.3155, grad_fn=<AddBackward0>) total loss:tensor(53.5924, grad_fn=<AddBackward0>)
# 146 epoch_loss:tensor(0.3155, grad_fn=<AddBackward0>) total loss:tensor(53.9079, grad_fn=<AddBackward0>)
# 147 epoch_loss:tensor(0.3155, grad_fn=<AddBackward0>) total loss:tensor(54.2233, grad_fn=<AddBackward0>)
# 148 epoch_loss:tensor(0.3154, grad_fn=<AddBackward0>) total loss:tensor(54.5388, grad_fn=<AddBackward0>)
# 149 epoch_loss:tensor(0.3154, grad_fn=<AddBackward0>) total loss:tensor(54.8542, grad_fn=<AddBackward0>)
# 150 epoch_loss:tensor(0.3154, grad_fn=<AddBackward0>) total loss:tensor(55.1695, grad_fn=<AddBackward0>)
# 151 epoch_loss:tensor(0.3153, grad_fn=<AddBackward0>) total loss:tensor(55.4849, grad_fn=<AddBackward0>)
# 152 epoch_loss:tensor(0.3153, grad_fn=<AddBackward0>) total loss:tensor(55.8002, grad_fn=<AddBackward0>)
# 153 epoch_loss:tensor(0.3153, grad_fn=<AddBackward0>) total loss:tensor(56.1155, grad_fn=<AddBackward0>)
# 154 epoch_loss:tensor(0.3153, grad_fn=<AddBackward0>) total loss:tensor(56.4308, grad_fn=<AddBackward0>)
# 155 epoch_loss:tensor(0.3152, grad_fn=<AddBackward0>) total loss:tensor(56.7460, grad_fn=<AddBackward0>)
# 156 epoch_loss:tensor(0.3152, grad_fn=<AddBackward0>) total loss:tensor(57.0612, grad_fn=<AddBackward0>)
# 157 epoch_loss:tensor(0.3152, grad_fn=<AddBackward0>) total loss:tensor(57.3764, grad_fn=<AddBackward0>)
# 158 epoch_loss:tensor(0.3152, grad_fn=<AddBackward0>) total loss:tensor(57.6916, grad_fn=<AddBackward0>)
# 159 epoch_loss:tensor(0.3152, grad_fn=<AddBackward0>) total loss:tensor(58.0068, grad_fn=<AddBackward0>)
# 160 epoch_loss:tensor(0.3151, grad_fn=<AddBackward0>) total loss:tensor(58.3219, grad_fn=<AddBackward0>)
# 161 epoch_loss:tensor(0.3151, grad_fn=<AddBackward0>) total loss:tensor(58.6370, grad_fn=<AddBackward0>)
# 162 epoch_loss:tensor(0.3151, grad_fn=<AddBackward0>) total loss:tensor(58.9521, grad_fn=<AddBackward0>)
# 163 epoch_loss:tensor(0.3151, grad_fn=<AddBackward0>) total loss:tensor(59.2672, grad_fn=<AddBackward0>)
# 164 epoch_loss:tensor(0.3151, grad_fn=<AddBackward0>) total loss:tensor(59.5823, grad_fn=<AddBackward0>)
# 165 epoch_loss:tensor(0.3150, grad_fn=<AddBackward0>) total loss:tensor(59.8973, grad_fn=<AddBackward0>)
# 166 epoch_loss:tensor(0.3150, grad_fn=<AddBackward0>) total loss:tensor(60.2123, grad_fn=<AddBackward0>)
# 167 epoch_loss:tensor(0.3150, grad_fn=<AddBackward0>) total loss:tensor(60.5273, grad_fn=<AddBackward0>)
# 168 epoch_loss:tensor(0.3150, grad_fn=<AddBackward0>) total loss:tensor(60.8423, grad_fn=<AddBackward0>)
# 169 epoch_loss:tensor(0.3150, grad_fn=<AddBackward0>) total loss:tensor(61.1572, grad_fn=<AddBackward0>)
# 170 epoch_loss:tensor(0.3149, grad_fn=<AddBackward0>) total loss:tensor(61.4722, grad_fn=<AddBackward0>)
# 171 epoch_loss:tensor(0.3149, grad_fn=<AddBackward0>) total loss:tensor(61.7871, grad_fn=<AddBackward0>)
# 172 epoch_loss:tensor(0.3149, grad_fn=<AddBackward0>) total loss:tensor(62.1020, grad_fn=<AddBackward0>)
# 173 epoch_loss:tensor(0.3149, grad_fn=<AddBackward0>) total loss:tensor(62.4169, grad_fn=<AddBackward0>)
# 174 epoch_loss:tensor(0.3149, grad_fn=<AddBackward0>) total loss:tensor(62.7317, grad_fn=<AddBackward0>)
# 175 epoch_loss:tensor(0.3149, grad_fn=<AddBackward0>) total loss:tensor(63.0466, grad_fn=<AddBackward0>)
# 176 epoch_loss:tensor(0.3148, grad_fn=<AddBackward0>) total loss:tensor(63.3614, grad_fn=<AddBackward0>)
# 177 epoch_loss:tensor(0.3148, grad_fn=<AddBackward0>) total loss:tensor(63.6762, grad_fn=<AddBackward0>)
# 178 epoch_loss:tensor(0.3148, grad_fn=<AddBackward0>) total loss:tensor(63.9910, grad_fn=<AddBackward0>)
# 179 epoch_loss:tensor(0.3148, grad_fn=<AddBackward0>) total loss:tensor(64.3058, grad_fn=<AddBackward0>)
# 180 epoch_loss:tensor(0.3148, grad_fn=<AddBackward0>) total loss:tensor(64.6206, grad_fn=<AddBackward0>)
# 181 epoch_loss:tensor(0.3148, grad_fn=<AddBackward0>) total loss:tensor(64.9354, grad_fn=<AddBackward0>)
# 182 epoch_loss:tensor(0.3147, grad_fn=<AddBackward0>) total loss:tensor(65.2501, grad_fn=<AddBackward0>)
# 183 epoch_loss:tensor(0.3147, grad_fn=<AddBackward0>) total loss:tensor(65.5648, grad_fn=<AddBackward0>)
# 184 epoch_loss:tensor(0.3147, grad_fn=<AddBackward0>) total loss:tensor(65.8795, grad_fn=<AddBackward0>)
# 185 epoch_loss:tensor(0.3147, grad_fn=<AddBackward0>) total loss:tensor(66.1942, grad_fn=<AddBackward0>)
# 186 epoch_loss:tensor(0.3147, grad_fn=<AddBackward0>) total loss:tensor(66.5089, grad_fn=<AddBackward0>)
# 187 epoch_loss:tensor(0.3147, grad_fn=<AddBackward0>) total loss:tensor(66.8236, grad_fn=<AddBackward0>)
# 188 epoch_loss:tensor(0.3147, grad_fn=<AddBackward0>) total loss:tensor(67.1382, grad_fn=<AddBackward0>)
# 189 epoch_loss:tensor(0.3146, grad_fn=<AddBackward0>) total loss:tensor(67.4529, grad_fn=<AddBackward0>)
# 190 epoch_loss:tensor(0.3146, grad_fn=<AddBackward0>) total loss:tensor(67.7675, grad_fn=<AddBackward0>)
# 191 epoch_loss:tensor(0.3146, grad_fn=<AddBackward0>) total loss:tensor(68.0821, grad_fn=<AddBackward0>)
# 192 epoch_loss:tensor(0.3146, grad_fn=<AddBackward0>) total loss:tensor(68.3967, grad_fn=<AddBackward0>)
# 193 epoch_loss:tensor(0.3146, grad_fn=<AddBackward0>) total loss:tensor(68.7113, grad_fn=<AddBackward0>)
# 194 epoch_loss:tensor(0.3146, grad_fn=<AddBackward0>) total loss:tensor(69.0259, grad_fn=<AddBackward0>)
# 195 epoch_loss:tensor(0.3146, grad_fn=<AddBackward0>) total loss:tensor(69.3405, grad_fn=<AddBackward0>)
# 196 epoch_loss:tensor(0.3146, grad_fn=<AddBackward0>) total loss:tensor(69.6550, grad_fn=<AddBackward0>)
# 197 epoch_loss:tensor(0.3145, grad_fn=<AddBackward0>) total loss:tensor(69.9696, grad_fn=<AddBackward0>)
# 198 epoch_loss:tensor(0.3145, grad_fn=<AddBackward0>) total loss:tensor(70.2841, grad_fn=<AddBackward0>)
# 199 epoch_loss:tensor(0.3145, grad_fn=<AddBackward0>) total loss:tensor(70.5986, grad_fn=<AddBackward0>)
# 200 epoch_loss:tensor(0.3145, grad_fn=<AddBackward0>) total loss:tensor(70.9131, grad_fn=<AddBackward0>)
# 201 epoch_loss:tensor(0.3145, grad_fn=<AddBackward0>) total loss:tensor(71.2276, grad_fn=<AddBackward0>)
# 202 epoch_loss:tensor(0.3145, grad_fn=<AddBackward0>) total loss:tensor(71.5421, grad_fn=<AddBackward0>)
# 203 epoch_loss:tensor(0.3145, grad_fn=<AddBackward0>) total loss:tensor(71.8565, grad_fn=<AddBackward0>)
# 204 epoch_loss:tensor(0.3145, grad_fn=<AddBackward0>) total loss:tensor(72.1710, grad_fn=<AddBackward0>)
# 205 epoch_loss:tensor(0.3144, grad_fn=<AddBackward0>) total loss:tensor(72.4855, grad_fn=<AddBackward0>)
# 206 epoch_loss:tensor(0.3144, grad_fn=<AddBackward0>) total loss:tensor(72.7999, grad_fn=<AddBackward0>)
# 207 epoch_loss:tensor(0.3144, grad_fn=<AddBackward0>) total loss:tensor(73.1143, grad_fn=<AddBackward0>)
# 208 epoch_loss:tensor(0.3144, grad_fn=<AddBackward0>) total loss:tensor(73.4287, grad_fn=<AddBackward0>)
# 209 epoch_loss:tensor(0.3144, grad_fn=<AddBackward0>) total loss:tensor(73.7431, grad_fn=<AddBackward0>)
# 210 epoch_loss:tensor(0.3144, grad_fn=<AddBackward0>) total loss:tensor(74.0575, grad_fn=<AddBackward0>)
# 211 epoch_loss:tensor(0.3144, grad_fn=<AddBackward0>) total loss:tensor(74.3719, grad_fn=<AddBackward0>)
# 212 epoch_loss:tensor(0.3144, grad_fn=<AddBackward0>) total loss:tensor(74.6863, grad_fn=<AddBackward0>)
# 213 epoch_loss:tensor(0.3144, grad_fn=<AddBackward0>) total loss:tensor(75.0007, grad_fn=<AddBackward0>)
# 214 epoch_loss:tensor(0.3144, grad_fn=<AddBackward0>) total loss:tensor(75.3150, grad_fn=<AddBackward0>)
# 215 epoch_loss:tensor(0.3144, grad_fn=<AddBackward0>) total loss:tensor(75.6294, grad_fn=<AddBackward0>)
# 216 epoch_loss:tensor(0.3143, grad_fn=<AddBackward0>) total loss:tensor(75.9437, grad_fn=<AddBackward0>)
# 217 epoch_loss:tensor(0.3143, grad_fn=<AddBackward0>) total loss:tensor(76.2581, grad_fn=<AddBackward0>)
# 218 epoch_loss:tensor(0.3143, grad_fn=<AddBackward0>) total loss:tensor(76.5724, grad_fn=<AddBackward0>)
# 219 epoch_loss:tensor(0.3143, grad_fn=<AddBackward0>) total loss:tensor(76.8867, grad_fn=<AddBackward0>)
# 220 epoch_loss:tensor(0.3143, grad_fn=<AddBackward0>) total loss:tensor(77.2010, grad_fn=<AddBackward0>)
# 221 epoch_loss:tensor(0.3143, grad_fn=<AddBackward0>) total loss:tensor(77.5153, grad_fn=<AddBackward0>)
# 222 epoch_loss:tensor(0.3143, grad_fn=<AddBackward0>) total loss:tensor(77.8296, grad_fn=<AddBackward0>)
# 223 epoch_loss:tensor(0.3143, grad_fn=<AddBackward0>) total loss:tensor(78.1439, grad_fn=<AddBackward0>)
# 224 epoch_loss:tensor(0.3143, grad_fn=<AddBackward0>) total loss:tensor(78.4582, grad_fn=<AddBackward0>)
# 225 epoch_loss:tensor(0.3143, grad_fn=<AddBackward0>) total loss:tensor(78.7724, grad_fn=<AddBackward0>)
# 226 epoch_loss:tensor(0.3143, grad_fn=<AddBackward0>) total loss:tensor(79.0867, grad_fn=<AddBackward0>)
# 227 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(79.4009, grad_fn=<AddBackward0>)
# 228 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(79.7152, grad_fn=<AddBackward0>)
# 229 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(80.0294, grad_fn=<AddBackward0>)
# 230 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(80.3436, grad_fn=<AddBackward0>)
# 231 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(80.6578, grad_fn=<AddBackward0>)
# 232 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(80.9720, grad_fn=<AddBackward0>)
# 233 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(81.2862, grad_fn=<AddBackward0>)
# 234 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(81.6004, grad_fn=<AddBackward0>)
# 235 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(81.9146, grad_fn=<AddBackward0>)
# 236 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(82.2288, grad_fn=<AddBackward0>)
# 237 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(82.5430, grad_fn=<AddBackward0>)
# 238 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(82.8571, grad_fn=<AddBackward0>)
# 239 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(83.1713, grad_fn=<AddBackward0>)
# 240 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(83.4854, grad_fn=<AddBackward0>)
# 241 epoch_loss:tensor(0.3141, grad_fn=<AddBackward0>) total loss:tensor(83.7996, grad_fn=<AddBackward0>)
# 242 epoch_loss:tensor(0.3141, grad_fn=<AddBackward0>) total loss:tensor(84.1137, grad_fn=<AddBackward0>)
# 243 epoch_loss:tensor(0.3141, grad_fn=<AddBackward0>) total loss:tensor(84.4279, grad_fn=<AddBackward0>)
# 244 epoch_loss:tensor(0.3141, grad_fn=<AddBackward0>) total loss:tensor(84.7420, grad_fn=<AddBackward0>)
# 245 epoch_loss:tensor(0.3141, grad_fn=<AddBackward0>) total loss:tensor(85.0561, grad_fn=<AddBackward0>)
# 246 epoch_loss:tensor(0.3141, grad_fn=<AddBackward0>) total loss:tensor(85.3702, grad_fn=<AddBackward0>)
# 247 epoch_loss:tensor(0.3141, grad_fn=<AddBackward0>) total loss:tensor(85.6843, grad_fn=<AddBackward0>)
# 248 epoch_loss:tensor(0.3141, grad_fn=<AddBackward0>) total loss:tensor(85.9984, grad_fn=<AddBackward0>)
# 249 epoch_loss:tensor(0.3141, grad_fn=<AddBackward0>) total loss:tensor(86.3125, grad_fn=<AddBackward0>)
# validation loss is equal to: tensor(0.5630, grad_fn=<NllLossBackward0>)
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94        18
#            1       0.88      1.00      0.93        14
#
#     accuracy                           0.94        32
#    macro avg       0.94      0.94      0.94        32
# weighted avg       0.95      0.94      0.94        32
