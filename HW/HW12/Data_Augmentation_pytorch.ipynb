# %% [markdown]
# # Training neural network: Data augmentation
#
# Tiếp nối bài thực hành trên lớp, bài tập về nhà này vẫn sử dụng MNIST là tập dữ liệu thử nghiệm. Mục tiêu là cải thiện hiệu suất của mô hình bằng các kỹ thuật Augmentation nhằm tăng cường số lượng dữ liệu

# %%
import warnings
warnings.filterwarnings('ignore')
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
from keras.datasets import mnist
import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %load_ext tensorboard
# !rm -rf './graph/dropout/dropout=0.5,relu/'

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print('Training image: ', x_train.shape)
print('Testing image: ', x_test.shape)
print('Training label: ', y_train.shape)
print('Testing label: ', y_test.shape)
# Out:
# Training image:  (60000, 28, 28)
# Testing image:  (10000, 28, 28)
# Training label:  (60000,)
# Testing label:  (10000,)

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
class SimpleModel(nn.Module):
    def __init__(self, dropout_rate):
        super(SimpleModel, self).__init__()
        self.dense_1 = nn.Linear(28*28, 128)
        self.dropout = nn.Dropout(dropout_rate)
        self.dense_2 = nn.Linear(128, 10)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = x.view(x.size(0), -1)
        x = self.dense_1(x)
        x = self.relu(x)
        x = self.dropout(x)
        output = F.log_softmax(self.dense_2(x))

        return output

# %% [markdown]
# # Check model parameter

# %%
simple_model = SimpleModel(dropout_rate = 0.5).cuda()
for param in simple_model.parameters():
    if param.requires_grad:
        print('param autograd')
        break

input = torch.rand(1, 28, 28).cuda()
output = simple_model(input)  # type: torch.Tensor

model_parameters = filter(lambda p: p.requires_grad, simple_model.parameters())
params = sum([np.prod(p.size()) for p in model_parameters])
print('Number of parameter:', params)
# Out:
# param autograd
# Number of parameter: 101770

# %% [markdown]
# ## Tăng thêm dữ liệu (data augmentation) với thư viện imgaug
#
# Trong phần thực hành này, chúng ta sẽ làm quen với các phương pháp tăng dữ liệu cho bài toán xử lý ảnh, các phương pháp này hoàn toàn có thể lập trình sử dụng thư viện numpy (vì bản chất của phương pháp là ta thao tác trên ma trận biểu diễn ảnh). Tuy nhiên, để việc lập trình được nhanh chóng, chúng ta sẽ làm quen với một thư viện rất mạnh mẽ, giúp ta nhanh chóng cài đặt nhiều phương pháp tăng dữ liệu hiệu quả khác nhau: thư viện imgaug
#
# Để cài đặt imgaug, ta sử dụng lệnh:
#
# pip install imgaug
#
# pip install scikit-image --upgrade

# %%
# Cài đặt thư viện

######################
### YOUR CODE HERE ###
######################
# !pip install imgaug

# !pip install scikit-image --upgrade
# Out:
# Collecting imgaug
#   Downloading imgaug-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from imgaug) (1.17.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.12/dist-packages (from imgaug) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from imgaug) (1.16.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from imgaug) (11.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from imgaug) (3.10.0)
# Requirement already satisfied: scikit-image>=0.14.2 in /usr/local/lib/python3.12/dist-packages (from imgaug) (0.25.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from imgaug) (4.12.0.88)
# Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (from imgaug) (2.37.0)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.12/dist-packages (from imgaug) (2.1.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.14.2->imgaug) (3.5)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.14.2->imgaug) (2025.10.16)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.14.2->imgaug) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.14.2->imgaug) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->imgaug) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->imgaug) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->imgaug) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->imgaug) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->imgaug) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->imgaug) (2.9.0.post0)
# Downloading imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 64.4 MB/s eta 0:00:00
# Installing collected packages: imgaug
# Successfully installed imgaug-0.4.0
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (2.0.2)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (1.16.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (3.5)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (2025.10.16)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (0.4)

# %%
# !pip install "numpy<2.0"
# Out:
# Collecting numpy<2.0
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 6.0 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 102.6 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.35.1 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4

# %%
from imgaug import augmenters as iaa

# %% [markdown]
# Để tìm hiểu lần lượt các phương pháp, thử áp dụng trên ảnh cat.jpg trong thư mục bài thực hành:

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !ls drive/My Drive/AIAcademy/AIAcademyDL02/
# Out:
# ls: cannot access 'drive/My Drive/AIAcademy/AIAcademyDL02/': No such file or directory

# %%
image = cv2.imread('./cat.jpg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ### Các phương pháp thường sử dụng
#
# Các phương pháp hay được sử dụng nhất trong các bài toán xử lý ảnh có thể tham khảo tại: https://imgaug.readthedocs.io/en/latest/source/augmenters.html

# %% [markdown]
# 1. CropAndPad: Cắt hoặc thêm các pixel vào ảnh.

# %%
# Sử dụng hàm CropAndPad với tham số percent=(-0.25, 0.25)

######################
### YOUR CODE HERE ###
crop_and_pad = iaa.CropAndPad(percent=(-0.25, 0.25))
######################

plt.imshow(cv2.cvtColor(crop_and_pad.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# 2. Flip: Flip left-right hoặc Flip up-down một số ảnh trong tập ảnh truyền vào

# %%
# Flip left-right sử dụng hàm Fliplr với tham số 1.0

######################
### YOUR CODE HERE ###
flip_lr = iaa.Fliplr(1.0)
######################

plt.imshow(cv2.cvtColor(flip_lr.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %%
# Flip up-down sử dụng hàm Flipud với tham số 1.0

######################
### YOUR CODE HERE ###
flip_ud = iaa.Flipud(1.0)
######################

plt.imshow(cv2.cvtColor(flip_ud.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - Affine: Các phép biến đổi affine như scale, rotate, translate:

# %%
# Biến đổi affine dùng hàm Affine với các tham số scale=(0.5, 1.5), rotate=(-15,15), translate_percent=(-0.2, 0.2)

######################
### YOUR CODE HERE ###
affine = iaa.Affine(scale=(0.5, 1.5), rotate=(-15,15), translate_percent=(-0.2, 0.2))
######################

plt.imshow(cv2.cvtColor(affine.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - Blur: Sử dụng các bộ lọc Gaussian hoặc Mean:

# %%
# Sử dụng hàm AverageBlur để thực hiện Mean filter với tham số k = (11,31), GaussianBlur để thực hiện Gausian Blur với Sigma = (5,15)

######################
### YOUR CODE HERE ###
avg_blur = iaa.AverageBlur(k=(11, 31))
gauss_blur = iaa.GaussianBlur(sigma=(5.0, 15.0))
######################

plt.imshow(cv2.cvtColor(avg_blur.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()
plt.imshow(cv2.cvtColor(gauss_blur.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - Dropout: Biến đổi ngẫu nhiên một phần ảnh thành các pixel đen

# %%
# Dropout với tham số p = (0, 0.2)

######################
### YOUR CODE HERE ###
dropout = iaa.Dropout(p=(0, 0.2))
######################

plt.imshow(cv2.cvtColor(dropout.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ### Kết hợp nhiều augmenter
#
# Trong thực tế, có nhiều chiến lược trong việc thực hiện các augmenter khác nhau, thư viện imgaug cũng hỗ trợ một số hàm để thực hiện công việc này:

# %% [markdown]
# - Sequential: Áp dụng các augmenter lần lượt theo thứ tự truyền vào:

# %%
aug = iaa.Sequential([
    iaa.Affine(translate_px={"x":(-40, 40)}),
    iaa.AdditiveGaussianNoise(scale=0.1*255)
])

plt.imshow(cv2.cvtColor(aug.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - SomeOf: Áp dụng ngẫu nhiên một vài augmenter trong list các augmenter:

# %%
if not hasattr(np, 'bool'):
    np.bool = np.bool_

# %%
aug = iaa.SomeOf(2, [
    iaa.Affine(rotate=45),
    iaa.AdditiveGaussianNoise(scale=0.2*255),
    iaa.Add(50, per_channel=True),
    iaa.Sharpen(alpha=0.5)
])

plt.imshow(cv2.cvtColor(aug.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - Sometimes: Áp dụng augmenter với xác suất p:

# %%
aug = iaa.Sometimes(0.5, iaa.GaussianBlur(sigma=20.0))

plt.imshow(cv2.cvtColor(aug.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ### Kết hợp cùng thư viện Keras
#
# Bây giờ chúng ta sẽ sử dụng các augmenter đã viết để thực hiện augment image trong quá trình huấn luyện mạng với thư viện Keras.

# %% [markdown]
# - Bước 1: Khởi tạo Augmenter:

# %%
 # Sử dụng hàm Dropout với tham số p=(0, 0.002)

######################
### YOUR CODE HERE ###
aug = iaa.Dropout(p=(0, 0.002))

######################

# %% [markdown]
# - Bước 2: Xây dựng generator:

# %%
class Generator(Dataset):
    def __init__(self, images, labels):
        self.images = images
        self.labels = labels

    def __len__(self):
        return self.images.shape[0]

    def __getitem__(self, idx):
        return self.images[idx], self.labels[idx]

# %%
training_data = Generator(x_train, y_train)
train_dataloader = DataLoader(training_data, batch_size=32, shuffle=True)

# %%
test_data = Generator(x_test, y_test)
test_dataloader = DataLoader(test_data, batch_size=32, shuffle=True)

# %% [markdown]
# Quan sát thử kết quả của generator bên trên:

# %%
for (batch_idx, target_tuple) in enumerate(train_dataloader):
    print(target_tuple[0].shape)
    for i in range(32):
        plt.subplot(4, 8, i + 1), plt.imshow(target_tuple[0][i], cmap='gray')
    plt.show()
    break
# Out:
# torch.Size([32, 28, 28])

# %% [markdown]
# - Bước 3: Train model với fit_generator:

# %%
use_cuda = torch.cuda.is_available()  #GPU cuda
best_loss = float('inf')

model = SimpleModel(dropout_rate = 0.5)

optimizer = torch.optim.Adadelta(model.parameters())

if use_cuda:
    model = torch.nn.parallel.DataParallel(model.cuda())   # , device_ids=[0, 1, 2, 3]
    torch.backends.cudnn.benchmark = True

# %%
def train(epoch):
    print('\n ############################# Train phase, Epoch: {} #############################'.format(epoch))
    model.train()
    train_loss = 0

    print('\nLearning rate at this epoch is: ', optimizer.param_groups[0]['lr'], '\n')

    for (batch_idx, target_tuple) in enumerate(train_dataloader):
        if use_cuda:
            target_tuple = [target_tensor.cuda(non_blocking=True) for target_tensor in target_tuple]

        images, labels = target_tuple
        # Convert label to long type pytorch
        labels = torch.tensor(labels,dtype=torch.long)

        optimizer.zero_grad()  # zero the gradient buff
        output_tuple = model(images)

        loss = F.nll_loss(output_tuple, labels).cuda()

        loss.backward()  # retain_graph=True
        optimizer.step()

        train_loss += loss.item()  # loss
        print('########################### Epoch:', epoch, ', --  batch:',  batch_idx, '/', len(train_dataloader), ',   ',
              'Train loss: %.3f, accumulated average loss: %.3f ##############################' % (loss.item(), train_loss / (batch_idx + 1)))

    global best_loss
    train_loss /= len(train_dataloader)
    if train_loss < best_loss:
      noti = 'best_'
      best_loss = train_loss
    else:
      noti = ''
    print('saving...')
    state = {
      'weights': model.module.state_dict(),
      'optimizer_weight': optimizer.state_dict(),
      'train_loss': train_loss,
      'epoch': epoch,
    }
    os.makedirs('checkpoints', exist_ok=True)
    torch.save(state, 'checkpoints/model_' + noti + str(epoch) + '_epoch.pth')

# %%
def test(epoch):
    print('\n ############################# Test phase, Epoch: {} #############################'.format(epoch))
    model.eval()
    with torch.no_grad():
        test_loss = 0

        for (batch_idx, target_tuple) in enumerate(test_dataloader):
            if use_cuda:
                target_tuple = [target_tensor.cuda(non_blocking=True) for target_tensor in target_tuple]

            images, labels = target_tuple
            # Convert label to long type pytorch
            labels = torch.tensor(labels,dtype=torch.long)
            output_tuple = model(images)

            loss = F.nll_loss(output_tuple, labels).cuda()

            test_loss += loss.item()  # loss
            print('########################### Epoch:', epoch, ', --  batch:',  batch_idx, '/', len(test_dataloader), ',   ',
                  'Test loss: %.3f, accumulated average loss: %.3f ##############################' % (loss.item(), test_loss / (batch_idx + 1)))

# %%
no_epoch = 5
for epoch in range(no_epoch):
    train(epoch)
    test(epoch)
# Out:
# Streaming output truncated to the last 5000 lines.
# ########################### Epoch: 2 , --  batch: 1583 / 1875 ,    Train loss: 0.259, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1584 / 1875 ,    Train loss: 0.312, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1585 / 1875 ,    Train loss: 0.441, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1586 / 1875 ,    Train loss: 0.076, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1587 / 1875 ,    Train loss: 0.274, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1588 / 1875 ,    Train loss: 0.213, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1589 / 1875 ,    Train loss: 0.241, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1590 / 1875 ,    Train loss: 0.152, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1591 / 1875 ,    Train loss: 0.146, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1592 / 1875 ,    Train loss: 0.295, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1593 / 1875 ,    Train loss: 0.343, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1594 / 1875 ,    Train loss: 0.025, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1595 / 1875 ,    Train loss: 0.027, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1596 / 1875 ,    Train loss: 0.438, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1597 / 1875 ,    Train loss: 0.126, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1598 / 1875 ,    Train loss: 0.377, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1599 / 1875 ,    Train loss: 0.444, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1600 / 1875 ,    Train loss: 0.159, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1601 / 1875 ,    Train loss: 0.093, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1602 / 1875 ,    Train loss: 0.291, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 
accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1737 / 1875 ,    Train loss: 0.329, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1738 / 1875 ,    Train loss: 0.136, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1739 / 1875 ,    Train loss: 0.020, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1740 / 1875 ,    Train loss: 0.701, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1741 / 1875 ,    Train loss: 0.190, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1742 / 1875 ,    Train loss: 0.119, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1743 / 1875 ,    Train loss: 0.345, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1744 / 1875 ,    Train loss: 0.004, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1745 / 1875 ,    Train loss: 0.124, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1746 / 1875 ,    Train loss: 0.095, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1747 / 1875 ,    Train loss: 0.053, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1748 / 1875 ,    Train loss: 0.181, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1749 / 1875 ,    Train loss: 0.156, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1750 / 1875 ,    Train loss: 0.365, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1751 / 1875 ,    Train loss: 0.319, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1752 / 1875 ,    Train loss: 0.340, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1753 / 1875 ,    Train loss: 0.219, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1754 / 1875 ,    Train loss: 0.176, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1755 / 1875 ,    Train loss: 0.211, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1756 / 1875 ,    Train loss: 0.119, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1757 / 1875 ,    Train loss: 0.053, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1758 / 1875 ,    Train loss: 0.192, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1759 / 1875 ,    Train loss: 0.141, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1760 / 1875 ,    Train loss: 0.256, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1761 / 1875 ,    Train loss: 0.071, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1762 / 1875 ,    Train loss: 0.068, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1763 / 1875 ,    Train loss: 0.074, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1764 / 1875 ,    Train loss: 0.114, accumulated average loss: 0.200 ##############################
# ########################### Epoch: 2 , --  batch: 1765 / 1875 ,    Train loss: 0.020, accumulated average loss: 0.200 ##############################
# ########################### Epoch: 2 , --  batch: 1766 / 1875 ,    Train loss: 0.013, accumulated average loss: 0.200 ##############################
# ########################### Epoch: 2 , --  batch: 1767 / 1875 ,    Train loss: 0.106, accumulated average loss: 0.200 ##############################
# ########################### Epoch: 2 , --  batch: 1768 / 1875 ,    Train loss: 0.914, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1769 / 1875 ,    Train loss: 0.126, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1770 / 1875 ,    Train loss: 0.004, accumulated average loss: 0.200 ##############################
# ########################### Epoch: 2 , --  batch: 1771 / 1875 ,    Train loss: 0.251, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1772 / 1875 ,    Train loss: 0.106, accumulated average loss: 0.200 ##############################
# ########################### Epoch: 2 , --  batch: 1773 / 1875 ,    Train loss: 0.162, accumulated average loss: 0.200 ##############################
# ########################### Epoch: 2 , --  batch: 1774 / 1875 ,    Train loss: 0.249, accumulated average loss: 0.200 ##############################
# ########################### Epoch: 2 , --  batch: 1775 / 1875 ,    Train loss: 0.341, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1776 / 1875 ,    Train loss: 0.226, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1777 / 1875 ,    Train loss: 0.031, accumulated average loss: 0.200 ##############################
# ########################### Epoch: 2 , --  batch: 1778 / 1875 ,    Train loss: 0.061, accumulated average loss: 0.200 ##############################
# ########################### Epoch: 2 , --  batch: 1779 / 1875 ,    Train loss: 0.058, accumulated average loss: 0.200 ##############################
# ########################### Epoch: 2 , --  batch: 1780 / 1875 ,    Train loss: 0.238, accumulated average loss: 0.200 ##############################
# ########################### Epoch: 2 , --  batch: 1781 / 1875 ,    Train loss: 0.347, accumulated average loss: 0.200 ##############################
# ########################### Epoch: 2 , --  batch: 1782 / 1875 ,    Train loss: 0.164, accumulated average loss: 0.200 ##############################
accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1836 / 1875 ,    Train loss: 0.101, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1837 / 1875 ,    Train loss: 0.216, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1838 / 1875 ,    Train loss: 0.184, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1839 / 1875 ,    Train loss: 0.350, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1840 / 1875 ,    Train loss: 0.073, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1841 / 1875 ,    Train loss: 0.078, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1842 / 1875 ,    Train loss: 0.008, accumulated average loss: 0.200 ##############################
# ########################### Epoch: 2 , --  batch: 1843 / 1875 ,    Train loss: 0.326, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1844 / 1875 ,    Train loss: 0.022, accumulated average loss: 0.200 ##############################
# ########################### Epoch: 2 , --  batch: 1845 / 1875 ,    Train loss: 1.047, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1846 / 1875 ,    Train loss: 0.769, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1847 / 1875 ,    Train loss: 0.736, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1848 / 1875 ,    Train loss: 0.132, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1849 / 1875 ,    Train loss: 0.259, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1850 / 1875 ,    Train loss: 0.143, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1851 / 1875 ,    Train loss: 0.030, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1852 / 1875 ,    Train loss: 0.077, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1853 / 1875 ,    Train loss: 0.039, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1854 / 1875 ,    Train loss: 0.029, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1855 / 1875 ,    Train loss: 0.286, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1856 / 1875 ,    Train loss: 0.191, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1857 / 1875 ,    Train loss: 0.081, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1858 / 1875 ,    Train loss: 0.021, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1859 / 1875 ,    Train loss: 0.389, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1860 / 1875 ,    Train loss: 0.112, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1861 / 1875 ,    Train loss: 0.248, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1862 / 1875 ,    Train loss: 0.733, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1863 / 1875 ,    Train loss: 0.108, accumulated average loss: 0.201 ##############################
# ########################### Epoch: 2 , --  batch: 1864 / 1875 ,    Train loss: 1.068, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1865 / 1875 ,    Train loss: 0.047, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1866 / 1875 ,    Train loss: 0.786, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1867 / 1875 ,    Train loss: 0.395, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1868 / 1875 ,    Train loss: 0.346, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1869 / 1875 ,    Train loss: 0.051, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1870 / 1875 ,    Train loss: 0.083, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1871 / 1875 ,    Train loss: 0.131, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1872 / 1875 ,    Train loss: 0.398, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1873 / 1875 ,    Train loss: 0.713, accumulated average loss: 0.202 ##############################
# ########################### Epoch: 2 , --  batch: 1874 / 1875 ,    Train loss: 0.017, accumulated average loss: 0.202 ##############################
# saving...
#
#  ############################# Test phase, Epoch: 2 #############################
# ########################### Epoch: 2 , --  batch: 0 / 313 ,    Test loss: 0.403, accumulated average loss: 0.403 ##############################
# ########################### Epoch: 2 , --  batch: 1 / 313 ,    Test loss: 0.027, accumulated average loss: 0.215 ##############################
# ########################### Epoch: 2 , --  batch: 2 / 313 ,    Test loss: 0.205, accumulated average loss: 0.212 ##############################
# ########################### Epoch: 2 , --  batch: 3 / 313 ,    Test loss: 0.116, accumulated average loss: 0.188 ##############################
# ########################### Epoch: 2 , --  batch: 4 / 313 ,    Test loss: 0.009, accumulated average loss: 0.152 ##############################
# ########################### Epoch: 2 , --  batch: 5 / 313 ,    Test loss: 0.232, accumulated average loss: 0.165 ##############################
# ########################### Epoch: 2 , --  batch: 6 / 313 ,    Test loss: 0.091, accumulated average loss: 0.155 ##############################
# ########################### Epoch: 2 , --  batch: 7 / 313 ,    Test loss: 0.012, accumulated average loss: 0.137 ##############################
